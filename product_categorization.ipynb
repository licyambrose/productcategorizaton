# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('data/amazon_products_sampled_5k.csv')
df.head()
# Out:
#          asin                                              title  \
# 0  B00004TN9O                     PlayStation 2 Console Slim PS2
# 1  B0B124MVGC  Pysrych Stainless Steel 304 Cast Pipe Fitting,...
# 2  B091CQ9HN6  uxcell 8pcs Round Die Stock Handle Wrench Set,...
# 3  B00GRJ4RG6              Rfid Aluminum Wallet, Black, One Size
# 4  B07CKFVWP2            Wrap Scarf - Tribal Print MULTI-COLORED
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/81bwyLZcZG...
# 1  https://m.media-amazon.com/images/I/61XNhXBf2Z...
# 2  https://m.media-amazon.com/images/I/61gysWlt8+...
# 3  https://m.media-amazon.com/images/I/71IGzubex5...
# 4  https://m.media-amazon.com/images/I/71ZG3PYNRE...
#
#                              productURL  price  listPrice  category_id  \
# 0  https://www.amazon.com/dp/B00004TN9O   0.00        0.0          250
# 1  https://www.amazon.com/dp/B0B124MVGC  11.99        0.0          147
# ...

# %%
# Create the 'image_page' column by combining the folder name, ASIN, and file extension
df['image_page'] = 'images/' + df['asin'] + '.jpg'

# Display the first few rows to verify the new column
df.head()
# Out:
#          asin                                              title  \
# 0  B00004TN9O                     PlayStation 2 Console Slim PS2
# 1  B0B124MVGC  Pysrych Stainless Steel 304 Cast Pipe Fitting,...
# 2  B091CQ9HN6  uxcell 8pcs Round Die Stock Handle Wrench Set,...
# 3  B00GRJ4RG6              Rfid Aluminum Wallet, Black, One Size
# 4  B07CKFVWP2            Wrap Scarf - Tribal Print MULTI-COLORED
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/81bwyLZcZG...
# 1  https://m.media-amazon.com/images/I/61XNhXBf2Z...
# 2  https://m.media-amazon.com/images/I/61gysWlt8+...
# 3  https://m.media-amazon.com/images/I/71IGzubex5...
# 4  https://m.media-amazon.com/images/I/71ZG3PYNRE...
#
#                              productURL  price  listPrice  category_id  \
# 0  https://www.amazon.com/dp/B00004TN9O   0.00        0.0          250
# 1  https://www.amazon.com/dp/B0B124MVGC  11.99        0.0          147
# ...
